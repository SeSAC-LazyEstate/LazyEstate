# %% [markdown]
# ## 라이브러리 임포트

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
import json
import requests
import configparser
import re
from tqdm.auto import tqdm, trange
import pprint
import missingno as msno

# %% [markdown]
# # 데이터 전처리
#
# 1. **데이터 정제 (Cleaning)**
#     - **결측치 처리**: 결측값을 삭제하거나 대체
#     - **이상치 탐지 및 처리**: 예를 들어 z-score나 IQR(사분위범위) 방식을 사용해서 이상치를 탐지하고 처리
#     - **중복 데이터 처리**: 중복된 데이터를 제거
# 2. **데이터 변환 (Transformation)**
#     - **정규화**: 데이터의 범위를 [0, 1] 또는 [-1, 1]로 조정
#     - **표준화**: 평균이 0이고 표준편차가 1이 되도록 데이터를 변환
#     - **원-핫 인코딩**: 범주형 변수를 수치형 변수로 변환
#     - **특성 스케일링**: 특성의 범위를 조정
# 3. **데이터 축소 (Reduction)**
#     - **차원 축소**: PCA, t-SNE 등의 방식으로 데이터의 차원 축소
#     - **특성 선택**: 중요한 특성만을 선택하여 모델의 성능 향상
# 4. **데이터 파생 (Derivation)**
#     - 존재하는 변수를 기반으로 새로운 변수 생성
# 5. **데이터 통합 (Integration)**
#     - 여러 데이터 소스(테이블, 파일 등)을 하나로 통합

# %% [markdown]
# ## 1. 데이터 정제(Cleaning)

# %% [markdown]
# ### 데이터 불러오기

# %%
pd.set_option('mode.chained_assignment',  None)  # SettingWithCopyWarning 무시

# SQLAlchemy를 사용하여 데이터베이스 연결
engine = create_engine("mysql+pymysql://admin:lazyestate@database-1.cr1v98drjdof.ap-northeast-2.rds.amazonaws.com:3306/LE")

# houseinfo_raw 데이터를 DataFrame으로 받기
df_raw = pd.read_sql_table('houseinfo_raw', engine.connect())

# %% [markdown]
# ### 데이터 확인

# %%
df_raw.head()
# Out:
#    no     case_number property_type   city district neighborhood  \
# 0   1    2022-1408(1)           아파트  서울특별시      성동구          성수동
# 1   2   2022-53027(1)           아파트  서울특별시      성동구          금호동
# 2   3  2020-104683(1)           아파트  서울특별시      서초구          잠원동
# 3   4  2022-108221(1)           아파트  서울특별시       중구          황학동
# 4   5     2023-218(1)           아파트  서울특별시      강남구         압구정동
#
#   address_number apartment_block  floor  room  ... appraised_value  \
# 0              2            101동    8.0   804  ...      2147483647
# 1              1            302동    1.0   103  ...      1520000000
# 2          58-24            323동    2.0   210  ...      2003000000
# 3           2545            102동   27.0  2702  ...      1000000000
# 4            481             91동    6.0   604  ...      2147483647
#
#   minimum_bid_price  sale_price sale_rate number_of_bidders  land_m2  \
# 0        1872000000  2147483647       100                 1   40.122
# 1         972800000  1191000007        78                 8   59.530
# 2        2003000000  2147483647       110                 1   43.960
# 3         640000000   755224800        76                 7   11.410
# 4        2147483647  2147483647       108                 2   62.940
#
#    land_pyung  building_m2  building_pyung  \
# 0       12.14        84.77           25.64
# 1       18.01       114.57           34.66
# 2       13.30        76.40           23.11
# 3        3.45        59.94           18.13
# 4       19.04       111.50           33.73
#
#                                                image
# 0  http://img1.speedauction.co.kr/new_gamimg/2023...
# 1  http://img1.speedauction.co.kr/new_gamimg/2023...
# 2  http://img1.speedauction.co.kr/new_gamimg/2021...
# 3  http://img1.speedauction.co.kr/new_gamimg/2023...
# 4  http://img1.speedauction.co.kr/new_gamimg/2023...
#
# [5 rows x 26 columns]

# %%
df_raw.tail()
# Out:
#       no    case_number property_type   city district neighborhood  \
# 970  971   2020-1667(1)           아파트  서울특별시      양천구          신정동
# 971  972   2019-9300(1)           아파트  서울특별시      동작구          동작동
# 972  973   2019-5754(1)           아파트  서울특별시      은평구          녹번동
# 973  974  2019-52200(1)           아파트  서울특별시      은평구          진관동
# 974  975  2019-56363(1)           아파트  서울특별시      은평구          응암동
#
#     address_number apartment_block  floor  room  ... appraised_value  \
# 970            327           1319동    2.0   202  ...      1558000000
# 971            331            104동   14.0  1401  ...       888000000
# 972          279-1            102동    4.0   404  ...       471000000
# 973             10            741동    6.0   601  ...      1230000000
# 974         197-78              2동    2.0   202  ...       142000000
#
#     minimum_bid_price  sale_price sale_rate number_of_bidders  land_m2  \
# 970        1558000000  1650000000       106                 4   93.370
# 971         888000000   938000000       106                 6   44.322
# 972         376800000   475240000       101                10   31.060
# 973         984000000  1007010000        82                 2   31.060
# 974         113600000   131990000        93                 4   14.250
#
#      land_pyung  building_m2  building_pyung  \
# 970       28.24      124.550           37.68
# 971       13.41       84.950           25.70
# 972        9.40       78.800           23.84
# 973        9.40      167.620           50.71
# 974        4.31       26.355            7.97
#
#                                                  image
# 970  http://img1.speedauction.co.kr/new_gamimg/2020...
# 971  http://img1.speedauction.co.kr/new_gamimg/2020...
# 972  http://img1.speedauction.co.kr/new_gamimg/2020...
# 973  http://img1.speedauction.co.kr/new_gamimg/2020...
# 974  http://img1.speedauction.co.kr/new_gamimg/2020...
#
# [5 rows x 26 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   no                 975 non-null    int64
#  1   case_number        975 non-null    object
#  2   property_type      975 non-null    object
#  3   city               975 non-null    object
#  4   district           975 non-null    object
#  5   neighborhood       969 non-null    object
#  6   address_number     967 non-null    object
#  7   apartment_block    654 non-null    object
#  8   floor              934 non-null    float64
#  9   room               964 non-null    object
#  10  apartment_name     711 non-null    object
#  11  full_address       975 non-null    object
#  12  auction_date       975 non-null    datetime64[ns]
#  13  percentage         975 non-null    object
#  14  result             975 non-null    object
#  15  auction_count      975 non-null    int64
#  16  appraised_value    975 non-null    int64
#  17  minimum_bid_price  975 non-null    int64
#  18  sale_price         975 non-null    int64
#  19  sale_rate          975 non-null    int64
#  20  number_of_bidders  975 non-null    int64
#  21  land_m2            975 non-null    float64
#  22  land_pyung         975 non-null    float64
#  23  building_m2        975 non-null    float64
#  24  building_pyung     975 non-null    float64
#  25  image              975 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(7), object(13)
# memory usage: 198.2+ KB

# %%
df_raw.describe()
# Out:
#                no       floor  auction_count  appraised_value  \
# count  975.000000  934.000000     975.000000     9.750000e+02
# mean   488.000000    8.324411       1.026667     9.452939e+08
# std    281.602557    6.675025       1.156762     6.114470e+08
# min      1.000000    1.000000       0.000000     2.340000e+07
# 25%    244.500000    3.000000       0.000000     4.645000e+08
# 50%    488.000000    7.000000       1.000000     8.060000e+08
# 75%    731.500000   11.750000       2.000000     1.310000e+09
# max    975.000000   58.000000      11.000000     2.147484e+09
#
#        minimum_bid_price    sale_price   sale_rate  number_of_bidders  \
# count       9.750000e+02  9.750000e+02  975.000000         975.000000
# mean        7.945148e+08  8.913551e+08   95.120000           6.117949
# std         5.663898e+08  5.974174e+08   23.745462           7.581551
# min         8.187000e+06  1.850000e+07    9.000000           1.000000
# 25%         3.765600e+08  4.455700e+08   77.000000           2.000000
# 50%         6.400000e+08  7.321200e+08   95.000000           4.000000
# 75%         1.070000e+09  1.241490e+09  110.000000           8.000000
# max         2.147484e+09  2.147484e+09  230.000000          73.000000
#
#           land_m2  land_pyung  building_m2  building_pyung
# count  975.000000  975.000000   975.000000      975.000000
# mean    38.791834   11.734564    87.299732       26.408103
# std     24.023082    7.267138    46.633278       14.106615
# min      0.750000    0.230000     1.040000        0.310000
# 25%     23.151250    7.000000    59.610000       18.035000
# 50%     35.960000   10.880000    84.682400       25.620000
# 75%     48.533500   14.685000   114.020000       34.490000
# max    223.000000   67.460000   364.040000      110.120000

# %%
df = df_raw.set_index('no')
df
# Out:
#         case_number property_type   city district neighborhood address_number  \
# no
# 1      2022-1408(1)           아파트  서울특별시      성동구          성수동              2
# 2     2022-53027(1)           아파트  서울특별시      성동구          금호동              1
# 3    2020-104683(1)           아파트  서울특별시      서초구          잠원동          58-24
# 4    2022-108221(1)           아파트  서울특별시       중구          황학동           2545
# 5       2023-218(1)           아파트  서울특별시      강남구         압구정동            481
# ..              ...           ...    ...      ...          ...            ...
# 971    2020-1667(1)           아파트  서울특별시      양천구          신정동            327
# 972    2019-9300(1)           아파트  서울특별시      동작구          동작동            331
# 973    2019-5754(1)           아파트  서울특별시      은평구          녹번동          279-1
# 974   2019-52200(1)           아파트  서울특별시      은평구          진관동             10
# 975   2019-56363(1)           아파트  서울특별시      은평구          응암동         197-78
#
#     apartment_block  floor  room apartment_name  ... appraised_value  \
# no                                               ...
# 1              101동    8.0   804        강변임광아파트  ...      2147483647
# 2              302동    1.0   103          벽산아파트  ...      1520000000
# 3              323동    2.0   210         신반포아파트  ...      2003000000
# 4              102동   27.0  2702       롯데캐슬베네치아  ...      1000000000
# 5               91동    6.0   604          현대아파트  ...      2147483647
# ..              ...    ...   ...            ...  ...             ...
# 971           1319동    2.0   202      목동신시가지아파트  ...      1558000000
# 972            104동   14.0  1401   동작동금강케이씨씨아파트  ...       888000000
# 973            102동    4.0   404           None  ...       471000000
# 974            741동    6.0   601           None  ...      1230000000
# 975              2동    2.0   202         신동아아파트  ...       142000000
#
#     minimum_bid_price  sale_price sale_rate  number_of_bidders  land_m2  \
# no
# 1          1872000000  2147483647       100                  1   40.122
# 2           972800000  1191000007        78                  8   59.530
# 3          2003000000  2147483647       110                  1   43.960
# 4           640000000   755224800        76                  7   11.410
# 5          2147483647  2147483647       108                  2   62.940
# ..                ...         ...       ...                ...      ...
# 971        1558000000  1650000000       106                  4   93.370
# 972         888000000   938000000       106                  6   44.322
# 973         376800000   475240000       101                 10   31.060
# 974         984000000  1007010000        82                  2   31.060
# 975         113600000   131990000        93                  4   14.250
#
#      land_pyung  building_m2  building_pyung  \
# no
# 1         12.14       84.770           25.64
# 2         18.01      114.570           34.66
# 3         13.30       76.400           23.11
# 4          3.45       59.940           18.13
# 5         19.04      111.500           33.73
# ..          ...          ...             ...
# 971       28.24      124.550           37.68
# 972       13.41       84.950           25.70
# 973        9.40       78.800           23.84
# 974        9.40      167.620           50.71
# 975        4.31       26.355            7.97
#
#                                                  image
# no
# 1    http://img1.speedauction.co.kr/new_gamimg/2023...
# 2    http://img1.speedauction.co.kr/new_gamimg/2023...
# 3    http://img1.speedauction.co.kr/new_gamimg/2021...
# 4    http://img1.speedauction.co.kr/new_gamimg/2023...
# 5    http://img1.speedauction.co.kr/new_gamimg/2023...
# ..                                                 ...
# 971  http://img1.speedauction.co.kr/new_gamimg/2020...
# 972  http://img1.speedauction.co.kr/new_gamimg/2020...
# 973  http://img1.speedauction.co.kr/new_gamimg/2020...
# 974  http://img1.speedauction.co.kr/new_gamimg/2020...
# 975  http://img1.speedauction.co.kr/new_gamimg/2020...
#
# [975 rows x 25 columns]

# %% [markdown]
# **\[부가 설명] 부동산 경매 과정**
#
# - 경매 개시: 부동산 경매가 시작되는 단계입니다. 채권자가 채무자의 부채를 회수하기 위해 법원에 경매를 신청하게 됩니다.
# - 경매 진행: 부동산의 감정 평가가 이루어진 후, 시작 가격을 기준으로 경매가 진행됩니다.
# - 매각 결정: 최고 입찰자가 나타나면, 그에게 부동산이 매각되기로 결정됩니다.
# - 대금 납부: 최고 입찰자는 정해진 기간 내에 낙찰 금액을 납부해야 합니다.
# - 배당 절차: 낙찰 금액이 납부되면, 그 금액은 각종 채권자와 권리자들에게 배당됩니다. 이때의 배당 순위는 법적 규정과 해당 부동산에 대한 권리 설정 순서에 따라 결정됩니다.
# - 배당 종결: 모든 권리자들에게 배당이 완료되면 배당 절차가 종료됩니다. 이를 "배당 종결"이라고 합니다.
# - "배당 종결" 이후에는 해당 부동산과 관련된 경매 절차가 모두 종료된 것으로 간주되며, 이 부동산에 대한 추가적인 경매 관련 절차는 진행되지 않습니다.

# %%
df.result.value_counts()
# Out:
# 배당종결    809
# 매각      100
# 잔금납부     66
# Name: result, dtype: int64

# %%
# for column in df.columns:
#     print(f"Column: {column}")
#     print(df[column].value_counts())
#     print("-" * 50)

# %%
# for column in df.columns:
#     plt.figure(figsize=(10,6))
#     sns.countplot(data=df, x=column, order=df[column].value_counts().index)
#     plt.title(f"Value Counts for {column}")
#     plt.xticks(rotation=45)
#     plt.show()

# %%
# profile = ProfileReport(df, title="Pandas Profiling Report")
# profile.to_widgets()

# %% [markdown]
# ### 1.1 결측치 확인&처리

# %%
# 결측치 개수 확인
df.isnull().sum()
# Out:
# case_number            0
# property_type          0
# city                   0
# district               0
# neighborhood           6
# address_number         8
# apartment_block      321
# floor                 41
# room                  11
# apartment_name       264
# full_address           0
# auction_date           0
# percentage             0
# result                 0
# auction_count          0
# appraised_value        0
# minimum_bid_price      0
# sale_price             0
# sale_rate              0
# number_of_bidders      0
# land_m2                0
# land_pyung             0
# building_m2            0
# building_pyung         0
# image                  0
# dtype: int64

# %%
# 결측치 시각화
isnull_before = msno.matrix(df)
isnull_before
# Out:
# <Axes: >

# %%
# 결측치가 있는 행만 선택
df_missing_data = df[df.isnull().any(axis=1)]
print(df_missing_data.isnull().sum())  # 확인
df_missing_data
# Out:
# case_number            0
# property_type          0
# city                   0
# district               0
# neighborhood           6
# address_number         8
# apartment_block      321
# floor                 41
# room                  11
# apartment_name       264
# full_address           0
# auction_date           0
# percentage             0
# result                 0
# auction_count          0
# appraised_value        0
# minimum_bid_price      0
# sale_price             0
# sale_rate              0
# number_of_bidders      0
# land_m2                0
# land_pyung             0
# building_m2            0
# building_pyung         0
# image                  0
# dtype: int64
#         case_number property_type   city district neighborhood address_number  \
# no
# 8    2022-112435(1)           아파트  서울특별시      서초구          잠원동          32-22
# 15   2023-101999(1)           아파트  서울특별시      강남구          역삼동           None
# 17     2022-2083(1)           아파트  서울특별시      은평구          역촌동          36-37
# 21      2022-962(1)           아파트  서울특별시      송파구          마천동           22-3
# 25   2022-109735(1)           아파트  서울특별시      도봉구          쌍문동          639-1
# ..              ...           ...    ...      ...          ...            ...
# 964  2020-101215(1)           아파트  서울특별시     영등포구          양평동              3
# 967  2018-104051(1)           아파트  서울특별시      강서구          등촌동            715
# 968    2019-7393(1)           아파트  서울특별시     영등포구          당산동              5
# 973    2019-5754(1)           아파트  서울특별시      은평구          녹번동          279-1
# 974   2019-52200(1)           아파트  서울특별시      은평구          진관동             10
#
#     apartment_block  floor  room apartment_name  ... appraised_value  \
# no                                               ...
# 8              None    6.0   601          보미리전빌  ...      1810000000
# 15             None    NaN  None          디오빌역삼  ...       414000000
# 17             None    NaN   801           None  ...       427000000
# 21             None    9.0   901       한주리버뷰아파트  ...       700000000
# 25             None    3.0   302            아파트  ...       324000000
# ..              ...    ...   ...            ...  ...             ...
# 964            101동    4.0   408           None  ...       563000000
# 967            108동    4.0   401           None  ...       785000000
# 968            411동   24.0  2401           None  ...      1650000000
# 973            102동    4.0   404           None  ...       471000000
# 974            741동    6.0   601           None  ...      1230000000
#
#     minimum_bid_price  sale_price sale_rate  number_of_bidders  land_m2  \
# no
# 8          1158400000  1421370000        79                  6   48.980
# 15          331200000   411730090        99                 17    4.992
# 17          273280000   305000000        71                  2   18.890
# 21          448000000   539999999        77                  1   46.450
# 25          259200000   291499000        90                  3   35.630
# ..                ...         ...       ...                ...      ...
# 964         563000000   632111112       112                  4   17.423
# 967         785000000  1032000000       131                 32   61.660
# 968        1650000000  1672741001       101                  1   65.880
# 973         376800000   475240000       101                 10   31.060
# 974         984000000  1007010000        82                  2   31.060
#
#      land_pyung  building_m2  building_pyung  \
# no
# 8         14.82      115.240           34.86
# 15         1.51       36.960           11.18
# 17         5.71       64.280           19.44
# 21        14.05       64.320           19.46
# 25        10.78       83.055           25.12
# ..          ...          ...             ...
# 964        5.27       59.900           18.12
# 967       18.65      134.884           40.80
# 968       19.93      161.080           48.73
# 973        9.40       78.800           23.84
# 974        9.40      167.620           50.71
#
#                                                  image
# no
# 8    http://img1.speedauction.co.kr/new_gamimg/2023...
# 15   http://img1.speedauction.co.kr/new_gamimg/2023...
# 17   http://img1.speedauction.co.kr/new_gamimg/2023...
# 21   http://img1.speedauction.co.kr/new_gamimg/2023...
# 25   http://img1.speedauction.co.kr/new_gamimg/2023...
# ..                                                 ...
# 964  http://img1.speedauction.co.kr/new_gamimg/2020...
# 967  http://img1.speedauction.co.kr/new_gamimg/2019...
# 968  http://img1.speedauction.co.kr/new_gamimg/2020...
# 973  http://img1.speedauction.co.kr/new_gamimg/2020...
# 974  http://img1.speedauction.co.kr/new_gamimg/2020...
#
# [463 rows x 25 columns]

# %% [markdown]
# #### 1.1.1 주소 결측치 확인&처리
# 1. full_address에서 동, 층, 호수 정보 추출하여 결측치 입력
# 2. 카카오 openapi 서비스를 사용해 나머지 결측치 입력

# %%
# 주소 컬럼만 추출
address_columns= ['case_number', 'city', 'district', 'neighborhood', 'address_number', 'apartment_block', 'floor', 'room', 'apartment_name', 'full_address']
df_missing_data_address = df_missing_data[address_columns]
df_missing_data_address
# Out:
#         case_number   city district neighborhood address_number  \
# no
# 8    2022-112435(1)  서울특별시      서초구          잠원동          32-22
# 15   2023-101999(1)  서울특별시      강남구          역삼동           None
# 17     2022-2083(1)  서울특별시      은평구          역촌동          36-37
# 21      2022-962(1)  서울특별시      송파구          마천동           22-3
# 25   2022-109735(1)  서울특별시      도봉구          쌍문동          639-1
# ..              ...    ...      ...          ...            ...
# 964  2020-101215(1)  서울특별시     영등포구          양평동              3
# 967  2018-104051(1)  서울특별시      강서구          등촌동            715
# 968    2019-7393(1)  서울특별시     영등포구          당산동              5
# 973    2019-5754(1)  서울특별시      은평구          녹번동          279-1
# 974   2019-52200(1)  서울특별시      은평구          진관동             10
#
#     apartment_block  floor  room apartment_name  \
# no
# 8              None    6.0   601          보미리전빌
# 15             None    NaN  None          디오빌역삼
# 17             None    NaN   801           None
# 21             None    9.0   901       한주리버뷰아파트
# 25             None    3.0   302            아파트
# ..              ...    ...   ...            ...
# 964            101동    4.0   408           None
# 967            108동    4.0   401           None
# 968            411동   24.0  2401           None
# 973            102동    4.0   404           None
# 974            741동    6.0   601           None
#
#                                       full_address
# no
# 8           서울특별시 서초구 잠원동 32-22 6층601호 (잠원동,보미리전빌)
# 15         서울특별시 강남구 언주로 427, 17층1708호 (역삼동,디오빌역삼)
# 17                        서울특별시 은평구 역촌동 36-37 801호
# 21        서울특별시 송파구 마천동 22-3 9층901호 (마천동,한주리버뷰아파트)
# 25            서울특별시 도봉구 쌍문동 639-1 3층302호 (쌍문동,아파트)
# ..                                             ...
# 964   서울특별시 영등포구 양평동3가 55-1 경남아너스빌 제101동 제4층 제408호
# 967      서울특별시 강서구 등촌동 715 등촌동아이파크 제108동 제4층 제401호
# 968  서울특별시 영등포구 당산동5가 42 당산삼성래미안 제411동 제24층 제2401호
# 973      서울특별시 은평구 녹번동 279-1 해주드림빌 제102동 제4층 제404호
# 974    서울특별시 은평구 진관동 10 은평뉴타운 상림마을 제741동 제6층 제601호
#
# [463 rows x 10 columns]

# %% [markdown]
# ##### 1.1.1.1 full_address에서 동, 층, 호수 정보 추출

# %%
# 동, 층, 호 결측치 개수 확인
print('동:', df_missing_data_address['apartment_block'].isnull().sum())
print('층:', df_missing_data_address['floor'].isnull().sum())
print('호:', df_missing_data_address['room'].isnull().sum())
# Out:
# 동: 321
# 층: 41
# 호: 11

# %%
# 패턴 정의
pattern_block = r'(\d+동|제\d+동|\d+-\d+호)' 
pattern_floor = r' (제?\d+)층 ?'
pattern_room = r'(?:제?\d+층)?(\d{2,4}호)'

# 아파트 동, 층, 호수 추출
df_missing_data_address['apartment_block'] = df_missing_data_address['full_address'].apply(
    lambda x: re.search(pattern_block, x).group(1).replace("제", "") if re.search(pattern_block, x) else np.nan)
df_missing_data_address['floor'] = df_missing_data_address['full_address'].apply(
    lambda x: re.search(pattern_floor, x).group(1).replace("제", "") if re.search(pattern_floor, x) else np.nan)
df_missing_data_address['room'] = df_missing_data_address['full_address'].apply(
    lambda x: re.search(pattern_room, x).group(1).replace("제", "").replace("호", "") if re.search(pattern_room, x) else np.nan)

# 동 정보에서 "102-601호" 형식의 문자열을 "102동"으로 변경
df_missing_data_address['apartment_block'] = df_missing_data_address['apartment_block'].apply(
    lambda x: x.split('-')[0]+'동' if '-' in str(x) else x)

# 층 정보가 누락된 경우 호수 정보를 바탕으로 층 정보를 채움
mask_missing_floor = df_missing_data_address['floor'].isnull()
df_missing_data_address.loc[mask_missing_floor, 'floor'] = df_missing_data_address['room'][mask_missing_floor].apply(
    lambda x: x[:-2] if isinstance(x, str) else np.nan)

# 결과 확인
df_missing_data_address
# Out:
#         case_number   city district neighborhood address_number  \
# no
# 8    2022-112435(1)  서울특별시      서초구          잠원동          32-22
# 15   2023-101999(1)  서울특별시      강남구          역삼동           None
# 17     2022-2083(1)  서울특별시      은평구          역촌동          36-37
# 21      2022-962(1)  서울특별시      송파구          마천동           22-3
# 25   2022-109735(1)  서울특별시      도봉구          쌍문동          639-1
# ..              ...    ...      ...          ...            ...
# 964  2020-101215(1)  서울특별시     영등포구          양평동              3
# 967  2018-104051(1)  서울특별시      강서구          등촌동            715
# 968    2019-7393(1)  서울특별시     영등포구          당산동              5
# 973    2019-5754(1)  서울특별시      은평구          녹번동          279-1
# 974   2019-52200(1)  서울특별시      은평구          진관동             10
#
#     apartment_block floor  room apartment_name  \
# no
# 8               NaN     6   601          보미리전빌
# 15              NaN    17  1708          디오빌역삼
# 17              NaN     8   801           None
# 21              NaN     9   901       한주리버뷰아파트
# 25              NaN     3   302            아파트
# ..              ...   ...   ...            ...
# 964            101동     4   408           None
# 967            108동     4   401           None
# 968            411동    24  2401           None
# 973            102동     4   404           None
# 974            741동     6   601           None
#
#                                       full_address
# no
# 8           서울특별시 서초구 잠원동 32-22 6층601호 (잠원동,보미리전빌)
# 15         서울특별시 강남구 언주로 427, 17층1708호 (역삼동,디오빌역삼)
# 17                        서울특별시 은평구 역촌동 36-37 801호
# 21        서울특별시 송파구 마천동 22-3 9층901호 (마천동,한주리버뷰아파트)
# 25            서울특별시 도봉구 쌍문동 639-1 3층302호 (쌍문동,아파트)
# ..                                             ...
# 964   서울특별시 영등포구 양평동3가 55-1 경남아너스빌 제101동 제4층 제408호
# 967      서울특별시 강서구 등촌동 715 등촌동아이파크 제108동 제4층 제401호
# 968  서울특별시 영등포구 당산동5가 42 당산삼성래미안 제411동 제24층 제2401호
# 973      서울특별시 은평구 녹번동 279-1 해주드림빌 제102동 제4층 제404호
# 974    서울특별시 은평구 진관동 10 은평뉴타운 상림마을 제741동 제6층 제601호
#
# [463 rows x 10 columns]

# %%
# 동, 층, 호 결측치 개수 확인
print('동:', df_missing_data_address['apartment_block'].isnull().sum())
print('층:', df_missing_data_address['floor'].isnull().sum())
print('호:', df_missing_data_address['room'].isnull().sum())
# Out:
# 동: 293
# 층: 3
# 호: 7

# %%
# 직접 수정

# 수정하려는 주소와 해당 값들
address_values = {
    # 호 정보 직접 수정
    # '서울특별시 용산구 원효로4가 110-1 나동호 풍전아파트':(),
    '서울특별시 양천구 신월동 413-3 제2층 제2호':(np.nan, 2, '2'),
    '서울특별시 영등포구 신길동 340-1 다동 2층7호':('다동', 2, '7'),
    '서울특별시 용산구 한남동 1-35 유엔맨숀 제5층 제에이호':(np.nan, 5, '에이'),
    '서울특별시 영등포구 여의도동 11-1 순복음아파트 제13층 제2호':(np.nan, 13, '2'),
    '서울특별시 서대문구 홍제동 247-19 홍일아파트 제지하층':(np.nan, -1, np.nan),
    '서울특별시 용산구 이촌동 193-5 강서아파트 제1동호 내제지하층나동1호':('101동', -1, '1' ),
    
    # # 외 #필지
    # "서울특별시 서대문구 홍제동 132-5외 1필지 에이원아파트 제6층 제604호": ("에이원동", "6", "604호"),
    # "서울특별시 서초구 방배동 806-5외 2필지 윈저빌 제5,6층 제502호": ("윈저빌동", "5,6", "502호"),
    # "서울특별시 금천구 독산동 917-3외 3필지 해찬아파트 제6,7층 제601호": ("해찬아파트동", "6,7", "601호"),
    # "서울특별시 서초구 서초동 1506-47외 1필지 신구블레스벨리 제1층 제101호": ("신구블레스벨리동", "1", "101호"),
    # "서울특별시 마포구 신공덕동 167외 2필지 메트로디오빌 제23층 제2302호": ("메트로디오빌동", "23", "2302호"),

    # # 복층
    # "서울특별시 서초구 양재동 286-6 양재테크노아파트 제4,5층 제401호": ("양재테크노동", "4,5", "401호"),
    # "서울특별시 서초구 서초동 1496-24 트라움하우스3 제4,5층 제502호": ("트라움하우스동", "4,5", "502호"),
    # "서울특별시 서초구 서초동 1427-7 한승미메이드 제가동 제5,6층 제502호": ("가동", "5,6", "502호"),

    # 동 정보 수정
    "서울특별시 은평구 역촌동 62-16 3층 에이동308호": ('에이동', 3, '308'),
    "서울특별시 중랑구 상봉동 501 39층에이-이스트3903호 (상봉동,상봉 듀오트리스)": ('에이-이스트', 39, '3903'),
    "서울특별시 동대문구 장안동 580 씨동 12층1206호 (장안동,위더스빌)": ('씨동', 12, '1206'),
    "서울특별시 용산구 한강로2가 419 17층에이-1701호 (용산동5가,아스테리움용산)": ('에이동', 17, '1701'),
    "서울특별시 강남구 도곡동 467 비동 16층1603호 (도곡동,타워팰리스)": ('비동', 16, '1603'),
    "서울특별시 강남구 도곡동 467 씨동 54층5406호 (도곡동,타워팰리스)": ('씨동', 54, '5406'),
    "서울특별시 관악구 신림동 746-43 가동 9층 905호 (신림동,건영아파트)": ('가동', 9, '905'),
    "서울특별시 강남구 삼성동 87 사우스윙동 22층 2202호 (삼성동, 아이파크삼성동)": ('사우스윙동', 22, '2202'),
    "서울특별시 영등포구 여의도동 37 제에이동 제11층 제1105호 (여의도동, 미성아파트)": ('에이동', 11, '1105'),
    "서울특별시 용산구 동자동 45외 1필지 센트레빌아스테리움서울 제비동 제32층 제3201호": ('비동', 32, '3201'),
    "서울특별시 강남구 도곡동 467 타워팰리스 제비동 제39층 제3904호": ('비동', 39, '3904'),
    "서울특별시 강남구 삼성동 87 아이파크삼성동 제사우스윙동 제18층 제1803호": ('사우스윙동', 18, '1803'),
    "서울특별시 강남구 도곡동 467-6 대림아크로빌 제에이동 제15층 제1502호": ('에이동', 15, '1502'),
    "서울특별시 영등포구 여의도동 61 여의도금호리첸시아 제14층 제에이1403호": (np.nan, 14, '1403'),
    "서울특별시 영등포구 여의도동 42 한양아파트 제에이치동 제3층 제307호": ('에이치동', 3, '307'),
    "서울특별시 송파구 송파대로 345 근린생활시설1에이동 지1층비091호 (가락동,헬리오시티)": ('에이동', -1, '비091'),
    "서울특별시 용산구 이촌동 301-162 현대아파트(건축물대장상:현대맨숀) 제나동 제3층 제301호": ('나동', 3, '301'),
    "서울특별시 마포구 공덕동 467 롯데캐슬프레지던트 제15층 제에이-1502호": ('에이동', 15, '1502'),
    "서울특별시 강남구 도곡동 467 타워팰리스 제비동 제58층 제5806호": ('비동', 58, '5806'),
    # "서울특별시 노원구 월계동 448-3외 2필지 삼창아파트 제다동(통칭:C동) 제401호": (),
    "서울특별시 송파구 문정동 645-2 에이치비지니스파크 제지4층 제씨-비403호": ('씨동', -4, '비403'),
    "서울특별시 영등포구 여의도동 21-2 공작아파트 제에이동 제9층 제909호": ('에이동', 9, '909'),
    "서울특별시 광진구 광장동 135-1 현대리버빌 제에이동 제4층 제402호": ('에이동', 4, '402'),
    "서울특별시 서대문구 홍은동 277-145 교수아파트 에이동 제지하층 제비01호": ('에이동', -1, '비01'),
    "서울특별시 양천구 목동 905-22 목동트윈빌 제30층 제디-3004호": ('디동', 30, '3004'),
    "서울특별시 강남구 청담동 104-5외 1필지 삼호빌라 제씨동 제3층 제303호": ('씨동', 3, '303'),
    "서울특별시 강남구 도곡동 467-29 타워팰리스 제지동 제22층 제2207호": ('지동', 22, '2207'),
    "서울특별시 송파구 잠실동 40 갤러리아팰리스 제에이동 제33층 제3307호": ('에이동', 33, '3307'),
    "서울특별시 관악구 신림동 739 뉴서울아파트 제나동 제2층 제202호": ('나동', 2, '202'),
    "서울특별시 동대문구 장안동 372-9 청솔아파트 제에이동 제9층 제901호": ('에이동', 9, '901'),
    "서울특별시 용산구 한남동 72-1 한남동리첸시아 제11층 제씨-1102호": ('씨동', 11, '1102'),

    # 지하
    "서울특별시 용산구 원효로1가 17-66 지하1층비101호 (원효로1가,원효로1가 로얄카운티-3)": (np.nan, -1, "비101")

}

# 각 주소의 값을 수정
for address, (block, floor, room) in address_values.items():
    index_to_modify = df_missing_data_address[df_missing_data_address['full_address'] == address].index[0]
    df_missing_data_address.loc[index_to_modify, 'apartment_block'] = block
    df_missing_data_address.loc[index_to_modify, 'floor'] = floor
    df_missing_data_address.loc[index_to_modify, 'room'] = room

# %%
# 동, 층, 호 결측치 개수 확인
print('동:', df_missing_data_address['apartment_block'].isnull().sum())
print('층:', df_missing_data_address['floor'].isnull().sum())
print('호:', df_missing_data_address['room'].isnull().sum())
# Out:
# 동: 263
# 층: 1
# 호: 2

# %%
display(
    df_missing_data_address[df_missing_data_address['apartment_block'].isnull()],
    df_missing_data_address[df_missing_data_address['room'].isnull()], 
    df_missing_data_address[df_missing_data_address['floor'].isnull()]
)
# Out:
#         case_number   city district neighborhood address_number  \
# no
# 8    2022-112435(1)  서울특별시      서초구          잠원동          32-22
# 15   2023-101999(1)  서울특별시      강남구          역삼동           None
# 17     2022-2083(1)  서울특별시      은평구          역촌동          36-37
# 21      2022-962(1)  서울특별시      송파구          마천동           22-3
# 25   2022-109735(1)  서울특별시      도봉구          쌍문동          639-1
# ..              ...    ...      ...          ...            ...
# 953    2019-8860(1)  서울특별시      양천구           목동         907-12
# 956    2019-3760(6)  서울특별시      관악구          신림동         1474-6
# 957  2019-101114(1)  서울특별시      강남구          삼성동          108-1
# 962  2019-106474(1)  서울특별시      강서구          화곡동         343-35
# 963  2019-108326(1)  서울특별시      구로구          구로동          797-9
#
#     apartment_block floor  room apartment_name  \
# no
# 8               NaN     6   601          보미리전빌
# 15              NaN    17  1708          디오빌역삼
# 17              NaN     8   801           None
# 21              NaN     9   901       한주리버뷰아파트
# 25              NaN     3   302            아파트
# ..              ...   ...   ...            ...
# 953             NaN    16  1601           None
# 956             NaN     9   902           None
# 957             NaN     3   301       삼성동아셈아파트
# 962             NaN     3   307      성재센트리움아파트
# 963             NaN     2   201           None
#
#                                       full_address
# no
# 8           서울특별시 서초구 잠원동 32-22 6층601호 (잠원동,보미리전빌)
# 15         서울특별시 강남구 언주로 427, 17층1708호 (역삼동,디오빌역삼)
# 17                        서울특별시 은평구 역촌동 36-37 801호
# 21        서울특별시 송파구 마천동 22-3 9층901호 (마천동,한주리버뷰아파트)
# 25            서울특별시 도봉구 쌍문동 639-1 3층302호 (쌍문동,아파트)
# ..                                             ...
# 953       서울특별시 양천구 목동 907-12 부영그린타운1차 제16층 제1601호
# 956          서울특별시 관악구 신림동 1474-6 삼성 아파트 제9층 제902호
# 957    서울특별시 강남구 삼성동 108-1외 1필지 삼성동아셈아파트 제3층 제301호
# 962  서울특별시 강서구 화곡동 343-35외 3필지 성재센트리움아파트 제3층 제307호
# 963                  서울특별시 구로구 구로동 797-9 제2층 제201호
#
# [263 rows x 10 columns]
#        case_number   city district neighborhood address_number  \
# no
# 62   2022-54893(1)  서울특별시      용산구           나동           None
# 668   2020-2232(1)  서울특별시     서대문구          홍제동         247-19
#
#     apartment_block floor room apartment_name  \
# no
# 62              NaN   NaN  NaN          풍전아파트
# 668             NaN    -1  NaN          홍일아파트
#
#                          full_address
# no
# 62    서울특별시 용산구 원효로4가 110-1 나동호 풍전아파트
# 668  서울특별시 서대문구 홍제동 247-19 홍일아파트 제지하층
#       case_number   city district neighborhood address_number apartment_block  \
# no
# 62  2022-54893(1)  서울특별시      용산구           나동           None             NaN
#
#    floor room apartment_name                     full_address
# no
# 62   NaN  NaN          풍전아파트  서울특별시 용산구 원효로4가 110-1 나동호 풍전아파트

# %%
# 채워진 결측치 정보 df에 반영
df.update(df_missing_data_address)

# %% [markdown]
# ##### 1.1.1.2 카카오 openapi 서비스를 사용해 나머지 결측치 입력

# %%
# 카카오 api에 주소 검색하기 위해 full_address에서 번지주소까지만 잘라낸 cleaned_address 생성
df.cleaned_address = [re.search(r'([\w\s가-힣-]+? \d+-?\d*)', address).group(1) if re.search(r'([\w\s가-힣-]+? \d+-?\d*)', address) else address for address in df.full_address]
# df.cleaned_address

# %%
# kakao api key가 담긴 파일에서 api key 읽어오기


# ConfigParser 객체 생성
config = configparser.ConfigParser()

# config.ini 파일 읽기
config.read('config.ini')

# 값을 가져오기
kakao_api_key = config['kakao_api_key']['kakao_api_key']

# %%
# kakao api를 사용하여 full_address를 검색하고 상세 정보 받아오기
kakao_response = {}

for no, address in tqdm(zip(df.index, df.cleaned_address), total=len(df)):
    url = f'https://dapi.kakao.com/v2/local/search/address.json?query={address}'
    headers = {
        "Authorization": "KakaoAK " + kakao_api_key
    }
    response = requests.get(url, headers=headers).json()
    
    
    kakao_response[no]=response
# Out:
#   0%|          | 0/975 [00:00<?, ?it/s]

# %%
# 카카오 api로 받아온 정보를 json파일로 저장

with open('kakao_response.json', 'w') as json_file:
    json.dump(kakao_response, json_file)

# %%
# JSON 파일에서 kakao_response 불러오기
with open('kakao_response.json', 'r') as json_file:
    kakao_response_loaded = json.load(json_file)

# %%
# 불러오지 못한 row 확인
empty_responses_indices = [no for no in df.index if not kakao_response_loaded[str(no)]['documents']]

print(f'카카오 api로 불러오지 못한 row 수: {len(empty_responses_indices)}')
# Out:
# 카카오 api로 불러오지 못한 row 수: 0

# %%
# 카카오 api로 불러온 정보 df에 입력


for no in df.index:
    documents = kakao_response_loaded.get(str(no), {}).get('documents', [{}])[0] or {}
    address = documents.get('address', {}) or {}
    road_address = documents.get('road_address', {}) or {}
    
    # 데이터를 딕셔너리 형태로 저장
    data = {
        'full_address_jibun': address.get('address_name', np.nan),  # 지번 주소
        'b_code': address.get('b_code', np.nan),  # 법정동 코드
        'h_code': address.get('h_code', np.nan),  # 행정동 코드
        'region1': address.get('region_1depth_name', np.nan),  # 시
        'region2': address.get('region_2depth_name', np.nan),  # 군/구
        'region3': address.get('region_3depth_name', np.nan),  # 동
        'main_address_no': address.get('main_address_no', np.nan),  # 번지 1
        'sub_address_no': address.get('sub_address_no', np.nan),  # 번자 2
        'full_address_road': road_address.get('address_name', np.nan),  # 도로명 풀주소
        'building_name': road_address.get('building_name', np.nan),  # 빌딩명
        'road_name': road_address.get('road_name', np.nan),  # 도로명
        'main_building_no': road_address.get('main_building_no', np.nan),  # 도로명 본번
        'sub_building_no': road_address.get('sub_building_no', np.nan),  # 도로명 부번
        'postcode': road_address.get('zone_no', np.nan),  # 우편번호
        'latitude': address.get('y', np.nan),  # latitude
        'longitude': address.get('x', np.nan),  # longitude
        'mountain': True if address.get('mountain_yn') == 'Y' else False,  # 산지형 여부
        'underground': True if road_address.get('underground_yn') == 'Y' else False  # 지하여부
    }
    
    # DataFrame에 한 번에 할당
    for key, value in data.items():
        df.loc[no, key] = value

# %%
# 카카오 api엔 빌딩명 정보가 없지만 기존 데이터엔 있었다면 입력
mask = df['building_name'].isnull() & df['apartment_name'].notnull()
df.loc[mask, 'building_name'] = df.loc[mask, 'apartment_name']

df[mask][['apartment_name', 'building_name']]
# Out:
#     apartment_name building_name
# no
# 903         신반포아파트        신반포아파트

# %%
# 사용 컬람
cols = [
    'case_number',
    'property_type',
    # 'city',
    # 'district',
    # 'neighborhood',
    # 'address_number',
    # 'full_address',
    'auction_date',
    'percentage',
    'result',
    'auction_count',
    'appraised_value',
    'minimum_bid_price',
    'sale_price',
    'sale_rate',
    'number_of_bidders',
    'land_m2',
    'land_pyung',
    'building_m2',
    'building_pyung',
    'image',
    'full_address_jibun',
    'b_code',
    'h_code',
    'region1',
    'region2',
    'region3',
    'main_address_no',
    'sub_address_no',
    'apartment_block',
    'floor',
    'room',
    # 'apartment_name',
    'full_address_road',
    'building_name',
    'road_name',
    'main_building_no',
    'sub_building_no',
    'postcode',
    'latitude',
    'longitude',
    # 'mountain',
    # 'underground'
]

# %%
df = df.replace(['', None], np.nan)

# %%
# df로 적용
df = df[cols]
df.isnull().sum()
# Out:
# case_number             0
# property_type           0
# auction_date            0
# percentage              0
# result                  0
# auction_count           0
# appraised_value         0
# minimum_bid_price       0
# sale_price              0
# sale_rate               0
# number_of_bidders       0
# land_m2                 0
# land_pyung              0
# building_m2             0
# building_pyung          0
# image                   0
# full_address_jibun      0
# b_code                  0
# h_code                  0
# region1                 0
# region2                 0
# region3                 0
# main_address_no         0
# sub_address_no        614
# apartment_block       263
# floor                   2
# room                    2
# full_address_road       3
# building_name          32
# road_name               3
# main_building_no        3
# sub_building_no       869
# postcode                3
# latitude                0
# longitude               0
# dtype: int64

# %%
# 층 정보가 없는 row 확인
df[df['floor'].isnull()]
# Out:
#         case_number property_type auction_date percentage result  \
# no
# 62    2022-54893(1)           아파트   2023-07-18         80     매각
# 195  2021-103744(1)           아파트   2023-03-29         80   배당종결
#
#      auction_count  appraised_value  minimum_bid_price  sale_price  sale_rate  \
# no
# 62               1       1150000000          920000000   926600000         81
# 195              1       2016000000         1612800000  2030000000        101
#
#      ...  floor  room  full_address_road  building_name  road_name  \
# no   ...
# 62   ...    NaN   NaN   서울 용산구 원효로25길 14          풍전아파트     원효로25길
# 195  ...    NaN    25     서울 영등포구 63로 45       여의도시범아파트        63로
#
#     main_building_no sub_building_no postcode          latitude  \
# no
# 62                14             NaN    04362  37.5327883979196
# 195               45             NaN    07344   37.520693352724
#
#             longitude
# no
# 62   126.953885517831
# 195  126.937105491683
#
# [2 rows x 35 columns]

# %%
df = df.astype({
    'auction_date': 'datetime64[ns]',
    'percentage': 'int64',
    'latitude': 'float64',
    'longitude': 'float64'
})
df['floor'] = df['floor'].astype(float).astype('Int64')  # floor의 경우 NaN값이 포함되어 있어 float으로 변환 후 Nullable이 포함된 Int64로 바꿔주었다

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975 entries, 1 to 975
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   case_number         975 non-null    object
#  1   property_type       975 non-null    object
#  2   auction_date        975 non-null    datetime64[ns]
#  3   percentage          975 non-null    int64
#  4   result              975 non-null    object
#  5   auction_count       975 non-null    int64
#  6   appraised_value     975 non-null    int64
#  7   minimum_bid_price   975 non-null    int64
#  8   sale_price          975 non-null    int64
#  9   sale_rate           975 non-null    int64
#  10  number_of_bidders   975 non-null    int64
#  11  land_m2             975 non-null    float64
#  12  land_pyung          975 non-null    float64
#  13  building_m2         975 non-null    float64
#  14  building_pyung      975 non-null    float64
#  15  image               975 non-null    object
#  16  full_address_jibun  975 non-null    object
#  17  b_code              975 non-null    object
#  18  h_code              975 non-null    object
#  19  region1             975 non-null    object
#  20  region2             975 non-null    object
#  21  region3             975 non-null    object
#  22  main_address_no     975 non-null    object
#  23  sub_address_no      361 non-null    object
#  24  apartment_block     712 non-null    object
#  25  floor               973 non-null    Int64
#  26  room                973 non-null    object
#  27  full_address_road   972 non-null    object
#  28  building_name       943 non-null    object
#  29  road_name           972 non-null    object
#  30  main_building_no    972 non-null    object
#  31  sub_building_no     106 non-null    object
#  32  postcode            972 non-null    object
#  33  latitude            975 non-null    float64
#  34  longitude           975 non-null    float64
# dtypes: Int64(1), datetime64[ns](1), float64(6), int64(7), object(20)
# memory usage: 307.5+ KB

# %%
df
# Out:
#         case_number property_type auction_date  percentage result  \
# no
# 1      2022-1408(1)           아파트   2023-08-14          80     매각
# 2     2022-53027(1)           아파트   2023-08-14          64     매각
# 3    2020-104683(1)           아파트   2023-08-10         100     매각
# 4    2022-108221(1)           아파트   2023-08-10          64     매각
# 5       2023-218(1)           아파트   2023-08-10         100     매각
# ..              ...           ...          ...         ...    ...
# 971    2020-1667(1)           아파트   2020-08-12         100   배당종결
# 972    2019-9300(1)           아파트   2020-08-11         100   배당종결
# 973    2019-5754(1)           아파트   2020-08-11          80   배당종결
# 974   2019-52200(1)           아파트   2020-08-11          80   배당종결
# 975   2019-56363(1)           아파트   2020-08-11          80   배당종결
#
#      auction_count  appraised_value  minimum_bid_price  sale_price  sale_rate  \
# no
# 1                1       2147483647         1872000000  2147483647        100
# 2                2       1520000000          972800000  1191000007         78
# 3                0       2003000000         2003000000  2147483647        110
# 4                2       1000000000          640000000   755224800         76
# 5                0       2147483647         2147483647  2147483647        108
# ..             ...              ...                ...         ...        ...
# 971              0       1558000000         1558000000  1650000000        106
# 972              0        888000000          888000000   938000000        106
# 973              1        471000000          376800000   475240000        101
# 974              1       1230000000          984000000  1007010000         82
# 975              1        142000000          113600000   131990000         93
#
#      ...  floor  room   full_address_road  building_name  road_name  \
# no   ...
# 1    ...      8   804      서울 성동구 둘레19길 5        강변임광아파트      둘레19길
# 2    ...      1   103      서울 성동구 금호로 100          벽산아파트        금호로
# 3    ...      2   210     서울 서초구 신반포로 257            뉴타운       신반포로
# 4    ...     27  2702      서울 중구 청계천로 400       롯데캐슬베네치아       청계천로
# 5    ...      6   604     서울 강남구 압구정로 309          현대아파트       압구정로
# ..   ...    ...   ...                 ...            ...        ...
# 971  ...      2   202     서울 양천구 목동동로 100  목동신시가지아파트13단지       목동동로
# 972  ...     14  1401  서울 동작구 동작대로39가길 55    동작동금강KCC아파트   동작대로39가길
# 973  ...      4   404      서울 은평구 응암로 366         해주 드림빌        응암로
# 974  ...      6   601   서울 은평구 진관4로 48-51     은평뉴타운 상림마을       진관4로
# 975  ...      2   202     서울 은평구 백련산로 127         신동아아파트       백련산로
#
#     main_building_no sub_building_no postcode   latitude   longitude
# no
# 1                  5             NaN    04776  37.535250  127.057006
# 2                100             NaN    04718  37.551693  127.027223
# 3                257             NaN    06523  37.509621  127.013278
# 4                400             NaN    04572  37.570978  127.021434
# 5                309             NaN    06006  37.531215  127.035439
# ..               ...             ...      ...        ...         ...
# 971              100             NaN    08096  37.514191  126.865003
# 972               55             NaN    06992  37.493987  126.978411
# 973              366             NaN    03459  37.603804  126.923082
# 974               48              51    03303  37.642403  126.931076
# 975              127             NaN    03463  37.596986  126.923484
#
# [975 rows x 35 columns]

# %%
# csv저장
df.to_csv('../../data/processed/houseinfo_auction/houseinfo.csv')

# %%
# db 저장
df.to_sql('houseinfo', engine, if_exists='replace', index=True)
# Out:
# 975

# %%
isnull_before
# Out:
# <Axes: >

# %%
isnull_after = msno.matrix(df)
isnull_after
# Out:
# <Axes: >
